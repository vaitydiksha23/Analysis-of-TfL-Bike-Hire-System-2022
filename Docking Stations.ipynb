# %%
import pandas as pd
import folium
from folium.plugins import MarkerCluster

# %%
stations = pd.read_csv('C:\Projects\Bike Hire\stations 2022.csv')
stations
# Out:
#                      Docking Station Name  Docking Station ID  \
# 0              River Street , Clerkenwell                   1
# 1          Phillimore Gardens, Kensington                   2
# 2    Christopher Street, Liverpool Street                   3
# 3         St. Chad's Street, King's Cross                   4
# 4           Sedding Street, Sloane Square                   5
# ..                                    ...                 ...
# 795                George Row, Bermondsey                 840
# 796               Tower Wharf, Bermondsey                 841
# 797                Temple Gardens, Temple                 842
# 798     Canada Water Station, Rotherhithe                 844
# 799        Bermondsey Station, Bermondsey                 845
#
#      Docking Station Capacity   Latitude  Longitude
# 0                          19  51.529200  -0.109971
# 1                          37  51.499600  -0.197574
# 2                          32  51.521300  -0.084606
# 3                          23  51.530100  -0.120974
# 4                          27  51.493100  -0.156876
# ..                        ...        ...        ...
# 795                        22  51.498585  -0.068982
# 796                        24  51.500845  -0.074704
# 797                        24  51.510981  -0.108323
# 798                        35  51.498439  -0.049150
# 799                        30  51.497995  -0.063471
#
# [800 rows x 5 columns]

# %%
# Change colours for stations based on capacity
def color(capacity):
    if(capacity < 15):
        return('red')
    elif(15 <= capacity < 30):
        return('orange')
    else:
        return('green')

# Create base map
London = [51.506949, -0.122876]
map = folium.Map(location = London,
                 zoom_start = 12, 
                 tiles = "CartoDB dark_matter")
docking_stations = folium.plugins.MarkerCluster().add_to(map)

# Plot markers
for lat, lon, cap, name, id in zip(stations["Latitude"], stations["Longitude"], stations["Docking Station Capacity"], 
                                    stations["Docking Station Name"], stations["Docking Station ID"]):
    folium.CircleMarker(location = [lat, lon], radius = 10, popup = "Capacity: ("+str(cap)+") "+ "ID: ("+str(id)+") "+name,
                    tooltip = str(name), fill_color = color(cap), 
                    fill_opacity= 1, color = "gray").add_to(docking_stations)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ecce9738bc04ab77cbfb43c430051d13 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ecce9738bc04ab77cbfb43c430051d13&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ecce9738bc04ab77cbfb43c430051d13 = L.map(
#                 &quot;map_ecce9738bc04ab77cbfb43c430051d13&quot;,
#                 {
#                     center: [51.506949, -0.122876],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f249a46960e7ae3c8a00ca820abe3baa = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f249a46960e7ae3c8a00ca820abe3baa.addTo(map_ecce9738bc04ab77cbfb43c430051d13);
#
#
#             var marker_cluster_6a5f1d45a35d62a796a945cf31befe34 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var circle_marker_f14764b9ec5cbf216e443dcfe0161e2c = L.circleMarker(
#                 [51.5292, -0.109971],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_6a5f1d45a35d62a796a945cf31befe34);
#
#
#         var popup_b4f7a12f8f4a33459bf6d36cfd965580 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_30eb8dc5702bdb47e3fab44f879b2242 = $(`&lt;div id=&quot;html_30eb8dc5702bdb47e3fab44f879b2242&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity: (19) ID: (1) River Street , Clerkenwell&lt;/div&gt;`)[0];
#                 popup_b4f7a12f8f4a33459bf6d36cfd965580.setContent(html_30eb8dc5702bdb47e3fab44f879b2242);
#
#
#
#         circle_marker_f14764b9ec5cbf216e443dcfe0161e2c.bindPopup(popup_b4f7a12f8f4a33459bf6d36cfd965580)
#         ;
#
#
#
#
#             circle_marker_f14764b9ec5cbf216e443dcfe0161e2c.bindTooltip(
#                 `&lt;div&gt;
#                      River Street , Clerkenwell
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_65ce53bf4facb08d3e5079bdd2f94775 = L.circleMarker(
#                 [51.4996, -0.197574],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_6a5f1d45a35d62a796a945cf31befe34);
#
#
#         var popup_14261a3d94c553546df5387be82f9a5d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_61f2becc22444c03de264bcf4f0a990d = $(`&lt;div id=&quot;html_61f2becc22444c03de264bcf4f0a990d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Capacity: (37) ID: (2) Phillimore Gardens, Kensington&lt;/div&gt;`)[0];
#                 popup_14261a3d94c553546df5387be82f9a5d.setContent(html_61f2becc22444c03de264bcf4f0a990d);
#
#
#
#         circle_marker_65ce53bf4facb08d3e5079bdd2f94775.bindPopup(popup_14261a3d94c553546df5387be82f9a5d)
#         ;
#
#
#
#
#             circle_marker_65ce53bf4facb08d3e5079bdd2f94775.bindTooltip(
#                 `&lt;div&gt;
#                      Phillimore Gardens, Kensington
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_518347a77710d6218bb3bb92a0751fda = L.circleMarker(
#                 [51.5213, -0.0846057],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&q
